# %% [markdown]
# # Chapter 7: Plotting

# %% [markdown]
# ### Udit Karthikeyan

# %% [raw]
# You can use the combination of MatPlotLib and NumPy to plot graphs and vizualize data.

# %%
import matplotlib.pyplot as plt
import numpy as np

#You can use plt.ion() to keep the plot interactive; that is, the terminal won't close and you can make many plots in a row
#It's best to use plt.ion() right after importing matplotlib.pyplot as plt, as it needs to be done before plotting

#plt.ion()

#If you wanted to get the data from a file, you could use:
#data = np.loadtxt(file_name)
#times = data[0]
#positions = data[1]

tarr = np.arange(1, 11) #This generates an array ranging from 1-10
parr = np.array([1,6, 5, 14, 31, 19, 10, 7, 62, 51]) #Generates an array with the points shown

#If using file data, you would replace tarr with times and parr with positions
plt.plot(tarr, parr) #you can enter a third argument to change how the data is shown
plt.show()

# %%
#You can enter a third argument in plt.plot to change how the data is represented. For example, "ro" makes the data into 
#red circles. You can also enter lables if you have different dependent variables: 
tarr = np.arange(1, 11) 
parr1 = np.array([8,3, 5, 15, 20, 8, 19, 7, 41, 33])
parr2 = np.array([1,6, 18, 14, 31, 19, 10, 7, 62, 51])

plt.plot(tarr, parr1, "ro", label="Planets") 
#If you want to plot two variables on different plots, you need to call plt.figure() in between the plots (between plotting
# and showing the first graph and plotting the second graph)
plt.plot(tarr, parr2, "b+", label="Asteroids") #"b+" represents the data as blue + marks

plt.legend() #Without this line, the labels will exist but not be shown on the plot. You can also input different numbers from
# 1-4 to change the location of the legend to different corners of the plot

plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_4472\2663512743.py in <module>
#       1 #You can enter a third argument in plt.plot to change how the data is represented. For example, "ro" makes the data into
#       2 #red circles. You can also enter lables if you have different dependent variables:
# ----> 3 tarr = np.arange(1, 11)
#       4 parr1 = np.array([8,3, 5, 15, 20, 8, 19, 7, 41, 33])
#       5 parr2 = np.array([1,6, 18, 14, 31, 19, 10, 7, 62, 51])
#
# NameError: name 'np' is not defined

# %%
#The plot function fills in extra information for us. Using subplot enables us to make more specific graphs.
fig, ax = plt.subplot()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_6372\1137168457.py in <module>
#       1 #The plot function fills in extra information for us. Using subplot enables us to make more specific graphs.
# ----> 2 fig, ax = plt.subplot()
#
# TypeError: cannot unpack non-iterable AxesSubplot object

# %%
plt.imshow(array, cmap="gray_r")

plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_4472\3063587732.py in <module>
# ----> 1 plt.imshow(array, cmap="gray_r")
#       2
#       3 plt.show()
#
# NameError: name 'plt' is not defined
